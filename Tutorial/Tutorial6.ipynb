# %%
for someChar in "Hello World":
  print(someChar)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for x in range(5):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mylist = "Hello World"
for i in range(len(mylist)):
  print(i,mylist[i])
# Out:
# 0 H
# 1 e
# 2 l
# 3 l
# 4 o
# 5
# 6 W
# 7 o
# 8 r
# 9 l
# 10 d

# %%
for (i, item) in enumerate(mylist):
  print(i,item)
# Out:
# 0 H
# 1 e
# 2 l
# 3 l
# 4 o
# 5
# 6 W
# 7 o
# 8 r
# 9 l
# 10 d
