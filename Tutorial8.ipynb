# %%
def myfun(x, y):
  return x * y

# %%
myfun(3, 4)
# Out:
# 12

# %%
def myfun(x):
  return x*3

# %%
def apply(q, x):
  return q(x)

# %%
apply(myfun, 7)
# Out:
# 21

# %%
apply(lambda z:z*4, 7)
# Out:
# 28

# %%
def myfun(b, c=3, d="hello"):
  return b+c

# %%
myfun(5,3,"hello")
# Out:
# 8

# %%
myfun(5,3)
# Out:
# 8

# %%
myfun(5)
# Out:
# 8

# %%
def myfun1(a, b, c):
  return a-b

# %%
myfun1(2,1,43)
# Out:
# 1

# %%
myfun1(c=43,b=1,a=2)
# Out:
# 1

# %%
myfun1(2, c=43, b=1)
# Out:
# 1

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
x = "abc"

# %%
y = 34

# %%
"%s xyz %d" %(x,y)
# Out:
# 'abc xyz 34'

# %%
print("%s xyz %d"%("abc", 34))
# Out:
# abc xyz 34

# %%
print("abc")
# Out:
# abc

# %%
print("abc","def")
# Out:
# abc def

# %%
print("abc",)
# Out:
# abc

# %%
";".join(["abc","def","ghi"])
# Out:
# 'abc;def;ghi'

# %%
"abc;def;ghi".split(";")
# Out:
# ['abc', 'def', 'ghi']

# %%
"Hello "+str(2)
# Out:
# 'Hello 2'

# %%
for e in [1,2]:
  print(e)
# Out:
# 1
# 2

# %%
s = [1,2]

# %%
it = iter(s)

# %%
it
