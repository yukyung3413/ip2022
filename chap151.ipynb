# %%
import cv2
import numpy as np

# %%
filename = 'chessboard.jpg'
img = cv2.imread(filename)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
filename = 'rim1.png'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

# %%
def nothing(x):
    pass

cv2.namedWindow('image')
cv2.createTrackbar('threshold', 'image', 10, 1000, nothing)
while(1):
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
    threshold = cv2.getTrackbarPos('threshold', 'image')
    if(threshold <= 1):
        threshold=1
    img = cv2.imread(filename)
    img[dst>1./threshold*dst.max()]=[0,0,255]
    cv2.imshow('image',img)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\U3\chap151.ipynb 셀 5 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/U3/chap151.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> if k == 27:
#       <a href='vscode-notebook-cell:/c%3A/Users/U3/chap151.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>     break
# ---> <a href='vscode-notebook-cell:/c%3A/Users/U3/chap151.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> threshold = cv2.getTrackbarPos('threshold', 'image')
#      <a href='vscode-notebook-cell:/c%3A/Users/U3/chap151.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> if(threshold <= 1):
#      <a href='vscode-notebook-cell:/c%3A/Users/U3/chap151.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     threshold=1
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2581: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu8.jpg')
sift = cv2.SIFT_create()
kp = sift.detect(gray,None)
imgsift = cv2.imread('dsu8.jpg')
imgsift=cv2.drawKeypoints(img,kp,imgsift,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize = (30,45))
plt.subplot(1,2,1),plt.imshow(img,cmap = 'gray')
plt.title('img'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(imgsift,cmap = 'gray')
plt.title('imgsift'), plt.xticks([]), plt.yticks([])
plt.show()
